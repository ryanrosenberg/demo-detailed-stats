# %%
import pandas as pd
import numpy as np
import json

# %%
with open('sample2.qbj', 'r') as f:
    qbj = json.load(f)

# %%
buzzes = []
for question in qbj['match_questions']:
    for buzz in question['buzzes']:
        buzzes.append(
            {
                'tossup': question['question_number'],
                'player': buzz['player']['name'],
                'team': buzz['team']['name'],
                'buzz_position': buzz['buzz_position']['word_index'],
                'value': str(buzz['result']['value'])
            }
        )
player_stats = pd.DataFrame(buzzes).groupby(
        ['player', 'team', 'value'], as_index=False
    ).agg('size').pivot(
        index=['player', 'team'], columns='value', values='size'
    ).reset_index()
player_stats
# Out:
# value                   player        team   -5    0   10
# 0             Aneesh Shrotriya   Iowa Gold  2.0  NaN  2.0
# 1                Brody Johnson  Kentucky B  NaN  NaN  3.0
# 2                   Caleb West  Kentucky B  NaN  1.0  3.0
# 3      Chakrapani Gudlavalleti  Kentucky B  NaN  1.0  4.0
# 4                Graham Truman   Iowa Gold  NaN  1.0  2.0
# 5                   Tony Kuker   Iowa Gold  NaN  1.0  1.0
# 6              William Parocai  Kentucky B  1.0  NaN  2.0

# %%
all_bonuses = [{'bonus': question['bonus'], 'question_number': question['question_number']} for question in qbj['match_questions'] if 'bonus' in question]
bonus_df = []
bonuses = []
for bonus in all_bonuses:
    bonus_df.append(
        {
            'tossup': bonus['question_number'],
            'bonus': bonus['bonus']['question']['question_number'],
            'value': sum([part['controlled_points'] for part in bonus['bonus']['parts']])
        }
    )

    bonuses.append(
        {
            'bonus': bonus['bonus']['question']['question_number'],
            'part': 1,
            'value': bonus['bonus']['parts'][0]['controlled_points']
        }
    )

    bonuses.append(
        {
            'bonus': bonus['bonus']['question']['question_number'],
            'part': 2,
            'value': bonus['bonus']['parts'][1]['controlled_points']
        }
    )

    bonuses.append(
        {
            'bonus': bonus['bonus']['question']['question_number'],
            'part': 3,
            'value': bonus['bonus']['parts'][2]['controlled_points']
        }
    )

team_bonuses = pd.DataFrame(bonus_df).merge(buzzes[buzzes['value'] == 10][['tossup', 'team']], on = 'tossup').groupby(['team'], as_index=False).agg(
    {'value': 'sum'}
).rename(columns={'value': 'BPts'})

team_bonuses
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [27], line 37
#      21     bonuses.append(
#      22         {
#      23             'bonus': bonus['bonus']['question']['question_number'],
#    (...)
#      26         }
#      27     )
#      29     bonuses.append(
#      30         {
#      31             'bonus': bonus['bonus']['question']['question_number'],
#    (...)
#      34         }
#      35     )
# ---> 37 team_bonuses = pd.DataFrame(bonus_df).merge(buzzes[buzzes['value' == 10]][['tossup', 'team']], on = 'tossup').groupby(['team'], as_index=False).agg(
#      38     {'value': 'sum'}
#      39 ).rename(columns={'value': 'BPts'})
#      41 team_bonuses
#
# TypeError: list indices must be integers or slices, not dict

# %%
qbj
# Out:
# {'tossups_read': 20,
#  'match_teams': [{'bonus_points': 110,
#    'lineups': [{'first_question': 1,
#      'players': [{'name': 'Griffin Reid'},
#       {'name': 'Robert Todd Oliver'},
#       {'name': 'Teerth Patel'},
#       {'name': 'Jonah Hubert'}]}],
#    'match_players': [{'player': {'name': 'Griffin Reid'},
#      'answer_counts': [{'answer': {'value': 10}, 'number': 2},
#       {'answer': {'value': -5}, 'number': 2}],
#      'tossups_heard': 20},
#     {'player': {'name': 'Robert Todd Oliver'},
#      'answer_counts': [{'answer': {'value': 10}, 'number': 2}],
#      'tossups_heard': 20},
#     {'player': {'name': 'Teerth Patel'},
#      'answer_counts': [{'answer': {'value': 10}, 'number': 2},
#       {'answer': {'value': -5}, 'number': 2}],
#      'tossups_heard': 20},
#     {'player': {'name': 'Jonah Hubert'},
#      'answer_counts': [{'answer': {'value': -5}, 'number': 1}],
#      'tossups_heard': 20}],
#    'team': {'name': 'Kentucky A',
#     'players': [{'name': 'Griffin Reid'},
#      {'name': 'Robert Todd Oliver'},
#      {'name': 'Teerth Patel'},
#      {'name': 'Jonah Hubert'}]}},
#   {'bonus_points': 190,
#    'lineups': [{'first_question': 1,
#      'players': [{'name': 'Arthur Gayden'},
#       {'name': 'Costas Pavlou'},
#       {'name': 'Yashwanth Bajji'},
#       {'name': 'Dennis Yang'}]}],
#    'match_players': [{'player': {'name': 'Arthur Gayden'},
#      'answer_counts': [{'answer': {'value': 10}, 'number': 9},
#       {'answer': {'value': -5}, 'number': 2}],
#      'tossups_heard': 20},
#     {'player': {'name': 'Costas Pavlou'},
#      'answer_counts': [{'answer': {'value': 10}, 'number': 2}],
#      'tossups_heard': 20},
#     {'player': {'name': 'Yashwanth Bajji'},
#      'answer_counts': [{'answer': {'value': -5}, 'number': 2},
#       {'answer': {'value': 10}, 'number': 2}],
#      'tossups_heard': 20},
#     {'player': {'name': 'Dennis Yang'},
#      'answer_counts': [{'answer': {'value': 10}, 'number': 1}],
#      'tossups_heard': 20}],
#    'team': {'name': 'Michigan',
#     'players': [{'name': 'Arthur Gayden'},
#      {'name': 'Costas Pavlou'},
#      {'name': 'Yashwanth Bajji'},
#      {'name': 'Dennis Yang'}]}}],
#  'match_questions': [{'buzzes': [{'buzz_position': {'word_index': 61},
#      'player': {'name': 'Dennis Yang'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 1,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 1},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 1},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 114},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 2,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 2},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 2},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 86},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 3,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 3},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 3},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 48},
#      'player': {'name': 'Yashwanth Bajji'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 144},
#      'player': {'name': 'Teerth Patel'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': 10}}],
#    'question_number': 4,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 4},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 4},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 85},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 127},
#      'player': {'name': 'Griffin Reid'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': 10}}],
#    'question_number': 5,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 5},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 5},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 94},
#      'player': {'name': 'Teerth Patel'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 124},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 6,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 6},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 6},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 100},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 117},
#      'player': {'name': 'Robert Todd Oliver'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': 10}}],
#    'question_number': 7,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 7},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 7},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 128},
#      'player': {'name': 'Robert Todd Oliver'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': 10}}],
#    'question_number': 8,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 8},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 8},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 100},
#      'player': {'name': 'Yashwanth Bajji'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 105},
#      'player': {'name': 'Teerth Patel'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': 10}}],
#    'question_number': 9,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 9},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 9},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 110},
#      'player': {'name': 'Griffin Reid'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 119},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 10,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 10},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 10},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 144},
#      'player': {'name': 'Griffin Reid'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 146},
#      'player': {'name': 'Costas Pavlou'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 11,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 11},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 11},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 134},
#      'player': {'name': 'Jonah Hubert'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 134},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 12,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 12},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 12},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 95},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 13,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 13},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 13},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 82},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 14,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 14},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 14},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 96},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 15,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 15},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 15},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 113},
#      'player': {'name': 'Arthur Gayden'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 16,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 16},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 16},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 86},
#      'player': {'name': 'Yashwanth Bajji'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 17,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 17},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 17},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 10},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 98},
#      'player': {'name': 'Griffin Reid'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': 10}}],
#    'question_number': 18,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 18},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 18},
#     'parts': [{'controlled_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 10}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 24},
#      'player': {'name': 'Costas Pavlou'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 19,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 19},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 19},
#     'parts': [{'controlled_points': 10},
#      {'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 0, 'bounceback_points': 0}]}},
#   {'buzzes': [{'buzz_position': {'word_index': 84},
#      'player': {'name': 'Teerth Patel'},
#      'team': {'name': 'Kentucky A',
#       'players': [{'name': 'Griffin Reid'},
#        {'name': 'Robert Todd Oliver'},
#        {'name': 'Teerth Patel'},
#        {'name': 'Jonah Hubert'}]},
#      'result': {'value': -5}},
#     {'buzz_position': {'word_index': 127},
#      'player': {'name': 'Yashwanth Bajji'},
#      'team': {'name': 'Michigan',
#       'players': [{'name': 'Arthur Gayden'},
#        {'name': 'Costas Pavlou'},
#        {'name': 'Yashwanth Bajji'},
#        {'name': 'Dennis Yang'}]},
#      'result': {'value': 10}}],
#    'question_number': 20,
#    'tossup_question': {'parts': 1, 'type': 'tossup', 'question_number': 20},
#    'bonus': {'question': {'parts': 3, 'type': 'bonus', 'question_number': 20},
#     'parts': [{'controlled_points': 0, 'bounceback_points': 0},
#      {'controlled_points': 10},
#      {'controlled_points': 10}]}}],
#  'packets': '2022 NASAT Round 01'}
